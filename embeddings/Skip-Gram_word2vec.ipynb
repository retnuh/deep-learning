# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils
from collections import Counter
import random

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:14, 2.09MB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
counts = Counter(int_words)
freqs = { i: counts[i]/len(words) for i in range(len(vocab_to_int)) }

# %%
[counts[vocab_to_int['the']], len(words)]
# Out:
# [1061396, 16680599]

# %%
words[15]
# Out:
# 'the'

# %%
np.random.seed(666)

# %%
## Your code here
def keep(freq, t=1e-5):
    x = np.sqrt(t/freq)
    r = np.random.random()
    return (x, r, r < x)

def foo(pos):
    return [freqs[int_words[pos]], words[pos], keep(freqs[int_words[pos]])]

for i in range(10):
    print(foo(i))
# Out:
# [1.8164815304294527e-05, 'anarchism', (0.74196685807510854, 0.7004371218578347, True)]
# [3.4291334501836536e-05, 'originated', (0.54001746604750078, 0.8441866428504345, False)]
# [0.007902294156223047, 'as', (0.035573238497455202, 0.6765143359376254, False)]
# [0.01953604903516954, 'a', (0.022624637612041264, 0.7278580572480748, False)]
# [0.00043277822337195443, 'term', (0.15200829932650489, 0.9514579574463393, False)]
# [0.035590868169662254, 'of', (0.016762188068664845, 0.012703197034767633, True)]
# [3.375178553240204e-05, 'abuse', (0.54431665569742305, 0.41358769878652346, True)]
# [0.0017271562010452981, 'first', (0.076091157720427599, 0.04881279380000003, True)]
# [0.0013630805464480023, 'used', (0.085652341552892905, 0.09992856132121142, False)]
# [0.0005054974344746253, 'against', (0.14065025442639176, 0.5080663057670065, False)]

# %%
train_words = [ int_words[i] for i in range(len(int_words)) if keep(freqs[int_words[i]])[2] ]
len(train_words)
# Out:
# 4626568

# %%
subsampled_count = Counter(train_words)
subsampled_count[0]
# Out:
# 13343

# %%
[int_to_vocab[2], subsampled_count[2], counts[2]]
# Out:
# ['and', 8338, 416629]

# %%
[np.max(train_words), len(vocab_to_int)]
# Out:
# [63640, 63641]

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    r = np.random.randint(window_size) + 1
    return words[idx-r:idx]+words[idx+1:idx+1+r]

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  200
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform([n_vocab, n_embedding], minval=-1, maxval=1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
[inputs.shape, embed.shape, labels.shape]
# Out:
# [TensorShape([Dimension(None)]),
#  TensorShape([Dimension(None), Dimension(200)]),
#  TensorShape([Dimension(None), Dimension(None)])]

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal([n_vocab, n_embedding], mean=0.0, stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, labels, embed, n_sampled, 
                                      num_classes=len(vocab_to_int), num_true=1)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.6002 0.2131 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.5966 0.0969 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.4452 0.0936 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.5511 0.0934 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.4355 0.0935 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.4911 0.0940 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.4813 0.0936 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.4950 0.0937 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.4542 0.0937 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.3955 0.0925 sec/batch
# Nearest to use: bamberg, prepositions, auden, therapeutic, covenant, contour, tus, beetle,
# Nearest to for: pendants, schottky, spades, fibrous, does, westmoreland, wenham, palestinian,
# Nearest to had: faring, grammaticus, chats, astor, unpaid, theological, mestizo, stability,
# Nearest to and: disconcerting, octopussy, sobib, accuracy, certificates, fermenting, cc, ard,
# Nearest to the: feasting, two, trevor, subunits, terrence, ammonites, sharks, ancestors,
# Nearest to have: magnate, lionheart, knowing, fore, thumbnails, ivar, uk, sunsets,
# Nearest to called: stacked, boas, comneni, modernise, ironic, darkest, america, cottingley,
# Nearest to first: ipod, commando, label, eugenio, trojans, affreightment, gandhara, consideration,
# Nearest to pre: bukhari, nursultan, samoa, anthology, aqua, qualifies, tax, bernese,
# Nearest to report: motel, mira, glacial, masoretic, cundinamarca, buying, straightened, hmc,
# Nearest to powers: behaving, table, tex, admirer, lumumba, neuroses, closest, decrease,
# Nearest to freedom: bordeaux, twenties, quiz, background, dinosauria, kasparov, simon, fail,
# Nearest to stage: maser, gleaned, kotor, odp, nagy, gemellus, jolla, methyl,
# Nearest to quite: imitates, albeniz, before, muluzi, fannie, monotonicity, salazar, kilo,
# Nearest to smith: assassination, caniformia, nucleotides, reclamation, japan, exploding, listed, rennie,
# Nearest to construction: hunky, geminated, auriga, biz, radclyffe, offensive, uncaring, merlot,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.4395 0.0940 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.3563 0.0923 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.2925 0.0921 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2308 0.0916 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.1622 0.0924 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.1668 0.0921 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.0762 0.0916 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.0429 0.0921 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0284 0.0923 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0063 0.0936 sec/batch
# Nearest to use: used, declined, contour, tracking, bamberg, therapeutic, iterations, covenant,
# Nearest to for: does, difference, concerned, schottky, pendants, empires, westmoreland, dependence,
# Nearest to had: faring, grammaticus, unpaid, astor, stability, theological, chats, wished,
# Nearest to and: accuracy, discussions, former, disconcerting, sobib, octopussy, manufacturing, certificates,
# Nearest to the: feasting, acceptance, raid, sharks, subunits, take, ancestors, germany,
# Nearest to have: uk, knowing, men, magnate, little, fore, act, tuner,
# Nearest to called: stacked, america, eat, boas, seemed, comneni, ironic, geometry,
# Nearest to first: label, consideration, ipod, all, commando, near, principles, erickson,
# Nearest to pre: tax, speakers, bukhari, anthology, closely, everyone, gosh, mythological,
# Nearest to report: glacial, clark, mira, motel, buying, cundinamarca, breach, tua,
# Nearest to powers: table, behaving, decrease, closest, tex, admirer, neuroses, lurking,
# Nearest to freedom: major, motion, fail, background, simon, quiz, composited, kasparov,
# Nearest to stage: maser, methyl, blocked, nagy, pandemic, time, jolla, committed,
# Nearest to quite: before, custom, software, imitates, kilo, minimum, deadly, we,
# Nearest to smith: assassination, japan, caniformia, nucleotides, listed, reclamation, irritable, especially,
# Nearest to construction: auriga, hunky, geminated, natural, radclyffe, offensive, biz, memorable,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9406 0.0947 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9054 0.0916 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.8923 0.0921 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.8787 0.0922 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8114 0.0919 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8032 0.0920 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8059 0.0921 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.7727 0.0921 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.7979 0.0926 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.7976 0.0949 sec/batch
# Nearest to use: used, contour, covenant, bamberg, tracking, prepositions, enlightenment, therapeutic,
# Nearest to for: does, pendants, schottky, empires, westmoreland, spades, concerned, dependence,
# Nearest to had: faring, unpaid, astor, grammaticus, chats, stability, wished, learned,
# Nearest to and: discussions, accuracy, octopussy, disconcerting, sobib, former, manufacturing, spanned,
# Nearest to the: raid, infinitesimal, subunits, extraordinary, botanical, sharks, rent, feasting,
# Nearest to have: knowing, uk, magnate, men, tuner, descriptive, fore, thumbnails,
# Nearest to called: stacked, boas, ironic, america, modernise, comneni, geometry, seemed,
# Nearest to first: label, commando, ipod, consideration, ag, eugenio, unjustly, alien,
# Nearest to pre: bukhari, anthology, tax, speakers, posited, qualifies, aqua, anonymity,
# Nearest to report: buying, glacial, mira, motel, clark, breach, abolitionist, cundinamarca,
# Nearest to powers: table, decrease, behaving, tex, closest, admirer, teach, neuroses,
# Nearest to freedom: major, quiz, motion, fail, simon, twenties, background, kasparov,
# Nearest to stage: maser, nagy, methyl, blocked, weapon, time, iconic, gleaned,
# Nearest to quite: custom, before, software, deadly, kilo, novelists, imitates, fishermen,
# Nearest to smith: assassination, japan, caniformia, nucleotides, listed, talents, reclamation, irritable,
# Nearest to construction: auriga, hunky, geminated, offensive, natural, biz, regimes, radclyffe,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.7723 0.0937 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.7842 0.0916 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7270 0.0923 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7080 0.0923 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.7514 0.0922 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7095 0.0918 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7400 0.0918 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7651 0.0917 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7075 0.0920 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6480 0.0919 sec/batch
# Nearest to use: used, prepositions, contour, therapeutic, covenant, enlightenment, bamberg, aerated,
# Nearest to for: does, pendants, spades, schottky, westmoreland, wenham, mess, palestinian,
# Nearest to had: faring, astor, unpaid, grammaticus, chats, wished, stability, came,
# Nearest to and: octopussy, disconcerting, discussions, spanned, accuracy, supersonic, meters, daytona,
# Nearest to the: raid, subunits, infinitesimal, botanical, armaments, feasting, extraordinary, painful,
# Nearest to have: knowing, tuner, magnate, uk, descriptive, lionheart, fore, sanctioned,
# Nearest to called: stacked, boas, ironic, comneni, modernise, undersea, america, geometry,
# Nearest to first: commando, label, ipod, trojans, ag, gandhara, unjustly, eugenio,
# Nearest to pre: bukhari, anthology, tax, nursultan, samoa, aqua, qualifies, speakers,
# Nearest to report: motel, mira, glacial, buying, clark, abolitionist, cundinamarca, ivanov,
# Nearest to powers: behaving, tex, decrease, table, neuroses, closest, admirer, railways,
# Nearest to freedom: quiz, major, mayer, kasparov, clarinet, fail, composited, simon,
# Nearest to stage: maser, gleaned, nagy, blocked, pandemic, weapon, iconic, methyl,
# Nearest to quite: custom, software, before, kilo, deadly, albeniz, imitates, monotonicity,
# Nearest to smith: assassination, japan, nucleotides, talents, listed, rennie, caniformia, reclamation,
# Nearest to construction: geminated, auriga, hunky, natural, radclyffe, campaigned, regimes, biz,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.6780 0.0935 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6769 0.0920 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6284 0.0912 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6217 0.0921 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6536 0.0919 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6041 0.0915 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.5865 0.0688 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5573 0.0920 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5100 0.0916 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5170 0.0916 sec/batch
# Nearest to use: used, prepositions, contour, therapeutic, rhetorically, bamberg, covenant, enlightenment,
# Nearest to for: does, pendants, schottky, spades, westmoreland, mess, wenham, screen,
# Nearest to had: astor, faring, chats, wished, unpaid, grammaticus, came, learned,
# Nearest to and: octopussy, supersonic, barbarians, meters, discussions, disconcerting, north, sobib,
# Nearest to the: raid, subunits, armaments, sharks, painful, infinitesimal, extraordinary, pangaea,
# Nearest to have: knowing, descriptive, lionheart, tuner, latch, sanctioned, sunsets, imposing,
# Nearest to called: stacked, modernise, boas, ironic, comneni, infects, america, darkest,
# Nearest to first: commando, ipod, peary, label, trojans, gandhara, oscars, carrier,
# Nearest to pre: bukhari, samoa, nursultan, tax, anthology, aqua, qualifies, dance,
# Nearest to report: glacial, motel, buying, mira, clark, ncr, cundinamarca, fide,
# Nearest to powers: behaving, decrease, neuroses, tex, table, admirer, frosts, closest,
# Nearest to freedom: quiz, mayer, clarinet, bordeaux, oxus, composited, major, kasparov,
# Nearest to stage: maser, gleaned, nagy, odp, iconic, jolla, blocked, pandemic,
# Nearest to quite: custom, software, albeniz, before, kilo, imitates, modeling, deadly,
# Nearest to smith: japan, assassination, talents, rennie, caniformia, nucleotides, listed, reclamation,
# Nearest to construction: natural, geminated, hunky, auriga, regimes, taunts, radclyffe, biz,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4994 0.0930 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4848 0.0917 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4514 0.0919 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5348 0.0951 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4997 0.0918 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4946 0.0924 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4424 0.0915 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3967 0.0918 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.4315 0.0918 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.4190 0.0924 sec/batch
# Nearest to use: used, prepositions, contour, therapeutic, beetle, bamberg, aerated, humiliating,
# Nearest to for: does, pendants, schottky, wenham, spades, concerned, screen, inflamed,
# Nearest to had: astor, faring, wished, unpaid, chats, flee, leaders, was,
# Nearest to and: octopussy, meters, supersonic, accuracy, barbarians, north, disconcerting, sobib,
# Nearest to the: raid, subunits, armaments, painful, dialogues, pangaea, extraordinary, infinitesimal,
# Nearest to have: descriptive, knowing, lionheart, latch, sunsets, tuner, sanctioned, raises,
# Nearest to called: stacked, modernise, infects, ironic, comneni, boas, geometry, deva,
# Nearest to first: label, ipod, peary, carrier, commando, gandhara, oscars, unjustly,
# Nearest to pre: bukhari, samoa, tax, nursultan, speakers, dance, mythological, organizing,
# Nearest to report: motel, glacial, mira, buying, clark, borgo, cundinamarca, hmc,
# Nearest to powers: behaving, neuroses, decrease, tex, frosts, railways, teach, admirer,
# Nearest to freedom: quiz, composited, oxus, bordeaux, clarinet, mayer, dinosauria, warlike,
# Nearest to stage: gleaned, maser, odp, nagy, lawn, iconic, intellectually, gambling,
# Nearest to quite: custom, albeniz, before, software, imitates, stalls, deadly, kilo,
# Nearest to smith: assassination, japan, rennie, talents, listed, masorti, caniformia, reclamation,
# Nearest to construction: natural, hunky, geminated, taunts, regimes, auriga, biz, most,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4201 0.0934 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.4125 0.0921 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4120 0.0917 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3824 0.0915 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3900 0.0916 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4378 0.0916 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3657 0.0935 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3672 0.0926 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3950 0.0927 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3652 0.0919 sec/batch
# Nearest to use: used, prepositions, therapeutic, bamberg, contour, aerated, superoxide, rhetorically,
# Nearest to for: does, schottky, pendants, mess, wenham, spades, concerned, screen,
# Nearest to had: astor, wished, faring, chats, unpaid, was, flee, learned,
# Nearest to and: octopussy, disconcerting, supersonic, discussions, in, ntsc, accuracy, intellectually,
# Nearest to the: raid, extraordinary, armaments, great, esquerra, repudiate, dialogues, infinitesimal,
# Nearest to have: knowing, descriptive, droppings, lionheart, sunsets, sanctioned, latch, men,
# Nearest to called: stacked, modernise, geometry, undersea, infects, boas, ironic, deva,
# Nearest to first: label, peary, ipod, gandhara, carrier, esa, commando, oscars,
# Nearest to pre: bukhari, speakers, nursultan, tax, samoa, mythological, organizing, dance,
# Nearest to report: motel, buying, mira, glacial, borgo, clark, breach, ivanov,
# Nearest to powers: behaving, neuroses, decrease, meritorious, tex, frosts, lurking, schooner,
# Nearest to freedom: quiz, oxus, warlike, flashlight, clarinet, composited, evolutionists, bayous,
# Nearest to stage: gleaned, maser, odp, time, nagy, lawn, gambling, jolla,
# Nearest to quite: custom, before, albeniz, synchrotron, stalls, software, deadly, kilo,
# Nearest to smith: assassination, japan, rennie, talents, listed, masorti, sandalwood, rev,
# Nearest to construction: natural, geminated, taunts, hunky, auriga, biz, addition, most,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3746 0.0931 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3919 0.0917 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3672 0.0920 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3564 0.0920 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3861 0.0915 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3517 0.0914 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3687 0.0929 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3757 0.0961 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3231 0.0974 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3014 0.0986 sec/batch
# Nearest to use: used, prepositions, aerated, superoxide, contour, document, bamberg, remedied,
# Nearest to for: pendants, schottky, does, spades, mess, wenham, westmoreland, concerned,
# Nearest to had: wished, astor, faring, was, flee, unpaid, chats, leaders,
# Nearest to and: in, octopussy, barbarians, supersonic, north, submission, meters, expanding,
# Nearest to the: esquerra, extraordinary, great, repudiate, infinitesimal, adoptions, raid, by,
# Nearest to have: knowing, latch, descriptive, droppings, lionheart, sunsets, uk, sanctioned,
# Nearest to called: modernise, stacked, geometry, comneni, infects, undersea, deva, ironic,
# Nearest to first: label, carrier, commando, peary, ipod, gandhara, esa, oscars,
# Nearest to pre: bukhari, speakers, samoa, mythological, organizing, tax, nursultan, dance,
# Nearest to report: motel, buying, mira, glacial, organizations, borgo, dea, hmc,
# Nearest to powers: behaving, neuroses, decrease, schooner, meritorious, papandreou, pbsuccess, campomanes,
# Nearest to freedom: oxus, bayous, fail, warlike, clarinet, dinosauria, major, crean,
# Nearest to stage: gleaned, maser, odp, time, jolla, lawn, nagy, iconic,
# Nearest to quite: custom, albeniz, before, deadly, synchrotron, stalls, homophonic, kilo,
# Nearest to smith: rennie, talents, assassination, japan, eddie, charlotte, rev, listed,
# Nearest to construction: natural, geminated, taunts, hunky, highway, auriga, averse, addition,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3144 0.0989 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2884 0.0970 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.4081 0.0979 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.4073 0.0978 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3918 0.0966 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2877 0.0977 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2862 0.0944 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.3366 0.0922 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1917 0.0919 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2916 0.0918 sec/batch
# Nearest to use: used, prepositions, aerated, purr, superoxide, contour, thinkpad, bamberg,
# Nearest to for: pendants, schottky, mess, does, wenham, spades, concerned, underestimate,
# Nearest to had: astor, faring, wished, flee, was, learned, leaders, unpaid,
# Nearest to and: octopussy, in, khyber, discussions, distorts, barbarians, kaliningrad, north,
# Nearest to the: esquerra, extraordinary, by, raid, repudiate, immortals, rent, handedly,
# Nearest to have: latch, lionheart, descriptive, magnate, sanctioned, knowing, droppings, sunsets,
# Nearest to called: modernise, stacked, geometry, ironic, deva, infects, ancestor, comneni,
# Nearest to first: label, carrier, peary, commando, oscars, gandhara, esa, apsaras,
# Nearest to pre: bukhari, speakers, nursultan, aara, mythological, samoa, dance, bernese,
# Nearest to report: buying, motel, organizations, mira, glacial, borgo, hmc, dea,
# Nearest to powers: neuroses, behaving, decrease, schooner, papandreou, meritorious, pbsuccess, campomanes,
# Nearest to freedom: fail, socialism, bayous, major, oxus, crean, clarinet, flashlight,
# Nearest to stage: gleaned, maser, odp, iconic, time, nagy, lawn, jolla,
# Nearest to quite: custom, albeniz, before, synchrotron, deadly, stalls, homophonic, software,
# Nearest to smith: rennie, talents, assassination, masorti, japan, eddie, rev, listed,
# Nearest to construction: natural, highway, taunts, hunky, geminated, auriga, averse, transportation,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2610 0.0925 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.3004 0.0919 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3288 0.0447 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2504 0.0919 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1870 0.0914 sec/batch
# Epoch 3/10 Iteration: 9600 Avg. Training loss: 4.2101 0.0922 sec/batch
# Epoch 3/10 Iteration: 9700 Avg. Training loss: 4.2169 0.0916 sec/batch
# Epoch 3/10 Iteration: 9800 Avg. Training loss: 4.1856 0.0912 sec/batch
# Epoch 3/10 Iteration: 9900 Avg. Training loss: 4.1987 0.0919 sec/batch
# Epoch 3/10 Iteration: 10000 Avg. Training loss: 4.1628 0.0920 sec/batch
# Nearest to use: used, prepositions, purr, contour, thinkpad, supercar, aerated, iterations,
# Nearest to for: pendants, schottky, mess, wenham, does, underestimate, spades, hindustan,
# Nearest to had: astor, faring, wished, was, flee, chats, grammaticus, learned,
# Nearest to and: north, meters, octopussy, in, kaliningrad, distorts, vanadium, maginot,
# Nearest to the: esquerra, by, indignation, great, adoptions, extraordinary, immortals, handedly,
# Nearest to have: lionheart, sunsets, latch, magnate, droppings, uk, descriptive, missiles,
# Nearest to called: modernise, stacked, ancestor, ironic, geometry, infects, integrating, america,
# Nearest to first: label, carrier, peary, oscars, chancellery, commando, all, gandhara,
# Nearest to pre: speakers, bukhari, nursultan, aara, mythological, bernese, samoa, dance,
# Nearest to report: mira, motel, buying, borgo, organizations, hmc, glacial, dea,
# Nearest to powers: behaving, neuroses, decrease, schooner, pbsuccess, papandreou, campomanes, frosts,
# Nearest to freedom: fail, flashlight, socialism, bayous, quiz, clarinet, mayer, composited,
# Nearest to stage: gleaned, time, maser, iconic, jolla, odp, simulated, intellectually,
# Nearest to quite: custom, albeniz, before, synchrotron, deadly, homophonic, stalls, imitates,
# Nearest to smith: rennie, assassination, talents, masorti, japan, listed, sammy, xix,
# Nearest to construction: highway, natural, taunts, hunky, transportation, russolo, auriga, geminated,
# Epoch 3/10 Iteration: 10100 Avg. Training loss: 4.2563 0.0929 sec/batch
# Epoch 3/10 Iteration: 10200 Avg. Training loss: 4.1900 0.0916 sec/batch
# Epoch 3/10 Iteration: 10300 Avg. Training loss: 4.2054 0.0916 sec/batch
# Epoch 3/10 Iteration: 10400 Avg. Training loss: 4.1088 0.0919 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1523 0.0932 sec/batch
# Epoch 3/10 Iteration: 10600 Avg. Training loss: 4.1270 0.0936 sec/batch
# Epoch 3/10 Iteration: 10700 Avg. Training loss: 4.1299 0.0922 sec/batch
# Epoch 3/10 Iteration: 10800 Avg. Training loss: 4.1578 0.0919 sec/batch
# Epoch 3/10 Iteration: 10900 Avg. Training loss: 4.1842 0.0917 sec/batch
# Epoch 3/10 Iteration: 11000 Avg. Training loss: 4.1351 0.0918 sec/batch
# Nearest to use: used, prepositions, purr, aerated, superoxide, therapeutic, contour, bamberg,
# Nearest to for: pendants, schottky, screen, mess, does, wenham, spades, timed,
# Nearest to had: astor, was, wished, faring, flee, chats, grammaticus, attempt,
# Nearest to and: discussions, octopussy, in, distorts, maginot, disadvantaged, preemptive, curit,
# Nearest to the: esquerra, extraordinary, yard, by, repudiate, rent, adoptions, cantona,
# Nearest to have: latch, droppings, descriptive, magnate, chinese, uk, urology, sunsets,
# Nearest to called: modernise, stacked, ancestor, infects, ironic, geometry, america, mocks,
# Nearest to first: carrier, label, peary, all, apsaras, oscars, commando, chancellery,
# Nearest to pre: speakers, bukhari, nursultan, aara, bernese, mythological, samoa, vlan,
# Nearest to report: motel, mira, borgo, buying, organizations, hmc, dea, breach,
# Nearest to powers: neuroses, behaving, pbsuccess, decrease, schooner, papandreou, campomanes, censured,
# Nearest to freedom: socialism, fail, bayous, flashlight, erred, quiz, houllier, absentee,
# Nearest to stage: gleaned, time, maser, iconic, jolla, odp, simulated, pitchfork,
# Nearest to quite: custom, albeniz, before, homophonic, synchrotron, stalls, middle, deadly,
# Nearest to smith: rennie, assassination, talents, masorti, claudine, pacino, sammy, xix,
# Nearest to construction: highway, natural, taunts, hunky, transportation, averse, expressways, russolo,
# Epoch 3/10 Iteration: 11100 Avg. Training loss: 4.1473 0.0927 sec/batch
# Epoch 3/10 Iteration: 11200 Avg. Training loss: 4.2084 0.0916 sec/batch
# Epoch 3/10 Iteration: 11300 Avg. Training loss: 4.1445 0.0915 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.1244 0.0911 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.1570 0.0916 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1961 0.0920 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1968 0.0914 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.1127 0.0930 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.1622 0.0914 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1339 0.0920 sec/batch
# Nearest to use: used, superoxide, prepositions, document, purr, aerated, keypad, bamberg,
# Nearest to for: mess, pendants, schottky, spades, wenham, does, screen, mcdonalds,
# Nearest to had: astor, was, faring, wished, flee, chats, grammaticus, unpaid,
# Nearest to and: discussions, octopussy, in, curit, maginot, preemptive, disadvantaged, north,
# Nearest to the: esquerra, extraordinary, by, infinitesimal, odum, of, repudiate, form,
# Nearest to have: droppings, uk, descriptive, tidy, urology, latch, magnate, clerks,
# Nearest to called: modernise, stacked, ancestor, ironic, converted, photonic, geometry, comneni,
# Nearest to first: carrier, label, peary, all, apsaras, oscars, commando, esa,
# Nearest to pre: bukhari, speakers, nursultan, mythological, aara, vlan, dance, organizing,
# Nearest to report: motel, mira, borgo, organizations, dea, hmc, buying, member,
# Nearest to powers: behaving, neuroses, decrease, pbsuccess, papandreou, frosts, schooner, censured,
# Nearest to freedom: fail, socialism, flashlight, bayous, erred, affective, critique, bioprospecting,
# Nearest to stage: gleaned, time, maser, iconic, pitchfork, nagy, shilton, simulated,
# Nearest to quite: albeniz, custom, homophonic, synchrotron, before, etymological, middle, superficially,
# Nearest to smith: rennie, talents, assassination, masorti, sammy, pacino, claudine, eddie,
# Nearest to construction: highway, natural, hunky, expressways, taunts, russolo, geminated, transportation,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.2039 0.0954 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1394 0.0916 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1398 0.0916 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1948 0.0914 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1466 0.0921 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0881 0.0921 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1524 0.0920 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0934 0.0921 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1745 0.0917 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.2086 0.0916 sec/batch
# Nearest to use: used, prepositions, superoxide, purr, document, thinkpad, keypad, aerated,
# Nearest to for: mess, pendants, spades, tabula, wenham, mcdonalds, schottky, hyphenated,
# Nearest to had: astor, was, wished, flee, faring, grammaticus, learned, restore,
# Nearest to and: in, octopussy, north, ocho, discussions, maginot, curit, timbered,
# Nearest to the: of, by, esquerra, extraordinary, syngman, anglicanism, adoptions, hilltop,
# Nearest to have: magnate, clerks, tidy, auxerre, lionheart, uk, kampuchea, descriptive,
# Nearest to called: ancestor, modernise, ironic, stacked, comneni, deva, integrating, birger,
# Nearest to first: carrier, peary, oscars, all, label, one, apsaras, nine,
# Nearest to pre: bukhari, speakers, nursultan, aara, mythological, vlan, bernese, samoa,
# Nearest to report: borgo, organizations, dea, mira, motel, member, haiku, hmc,
# Nearest to powers: behaving, neuroses, schooner, decrease, pbsuccess, papandreou, frosts, campomanes,
# Nearest to freedom: fail, bayous, rouen, flashlight, mayer, major, erred, critique,
# Nearest to stage: gleaned, maser, time, iconic, pitchfork, nagy, simulated, shilton,
# Nearest to quite: albeniz, custom, synchrotron, homophonic, etymological, before, stalls, deadly,
# Nearest to smith: rennie, assassination, masorti, talents, claudine, xix, sammy, pacino,
# Nearest to construction: highway, natural, hunky, expressways, taunts, russolo, transportation, acrylics,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1894 0.0932 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.0699 0.0916 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0991 0.0916 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.1220 0.0933 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 4.0390 0.0915 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1070 0.0916 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.1040 0.0931 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0887 0.0922 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1425 0.0207 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0850 0.0916 sec/batch
# Nearest to use: used, purr, document, prepositions, thinkpad, keypad, superoxide, printable,
# Nearest to for: mess, pendants, mcdonalds, schottky, underestimate, commutes, tabula, eraser,
# Nearest to had: astor, was, wished, faring, flee, grammaticus, restore, learned,
# Nearest to and: in, north, ocho, manufacturing, octopussy, discussions, fledgling, lietuvos,
# Nearest to the: of, by, esquerra, extraordinary, leste, fyrom, cantona, illuminated,
# Nearest to have: magnate, tidy, uk, sanctioned, lionheart, urology, latch, clerks,
# Nearest to called: stacked, ancestor, modernise, ironic, integrating, retrieves, photonic, deva,
# Nearest to first: peary, carrier, oscars, all, one, label, apsaras, nine,
# Nearest to pre: bukhari, speakers, nursultan, mythological, vlan, aara, dance, bernese,
# Nearest to report: dea, motel, mira, borgo, hmc, organizations, clark, haiku,
# Nearest to powers: neuroses, behaving, pbsuccess, schooner, papandreou, decrease, campomanes, censured,
# Nearest to freedom: flashlight, fail, socialism, bioprospecting, mayer, houllier, rouen, bayous,
# Nearest to stage: gleaned, time, simulated, maser, pitchfork, iconic, cure, nagy,
# Nearest to quite: albeniz, custom, homophonic, synchrotron, malley, middle, etymological, before,
# Nearest to smith: rennie, assassination, talents, xix, claudine, masorti, japan, eddie,
# Nearest to construction: highway, natural, hunky, expressways, taunts, russolo, transportation, mountainsides,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0570 0.0926 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0407 0.0919 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0502 0.0915 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 4.0242 0.0909 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0230 0.0922 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 4.0127 0.0919 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 4.0850 0.0917 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0950 0.0916 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.1121 0.0923 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9795 0.0914 sec/batch
# Nearest to use: used, purr, keypad, superoxide, document, bamberg, decibels, prepositions,
# Nearest to for: mess, pendants, schottky, commutes, tabula, factorials, mcdonalds, sometimes,
# Nearest to had: astor, was, wished, flee, faring, learned, umpires, nebulous,
# Nearest to and: in, north, sand, vanadium, earthquake, disadvantaged, timbered, style,
# Nearest to the: of, by, in, extraordinary, esquerra, also, be, a,
# Nearest to have: uk, tidy, latino, magnate, urology, latch, aerodrome, phased,
# Nearest to called: ancestor, modernise, stacked, comneni, ironic, integrating, detroiters, albinus,
# Nearest to first: carrier, peary, all, label, oscars, one, apsaras, autocephalous,
# Nearest to pre: bukhari, speakers, nursultan, mythological, bernese, aara, vlan, dance,
# Nearest to report: borgo, mira, hmc, motel, dea, suzuki, clark, haiku,
# Nearest to powers: neuroses, behaving, pbsuccess, schooner, papandreou, decrease, campomanes, admirer,
# Nearest to freedom: flashlight, socialism, boudica, houllier, bioprospecting, mayer, absentee, rouen,
# Nearest to stage: maser, gleaned, simulated, pitchfork, time, microprogram, nanometers, symphonie,
# Nearest to quite: albeniz, homophonic, custom, synchrotron, before, malley, middle, imitates,
# Nearest to smith: rennie, assassination, japan, claudine, masorti, clarion, eddie, xix,
# Nearest to construction: highway, expressways, natural, taunts, hunky, russolo, transportation, acrylics,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9828 0.0936 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 4.0186 0.0918 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9833 0.0911 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 4.0132 0.0926 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 4.0325 0.0929 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 4.0276 0.0919 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 4.0366 0.0923 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0835 0.0915 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0194 0.0918 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 4.0160 0.0919 sec/batch
# Nearest to use: used, purr, document, superoxide, keypad, bamberg, unheated, aerated,
# Nearest to for: mess, pendants, factorials, commutes, schottky, tabula, eraser, initialize,
# Nearest to had: astor, was, wished, faring, flee, learned, grammaticus, bologna,
# Nearest to and: in, discussions, style, disadvantaged, octopussy, salvadoran, gravely, dirigible,
# Nearest to the: of, extraordinary, by, an, is, a, be, repudiate,
# Nearest to have: uk, latino, magnate, urology, aerodrome, tidy, latch, sanctioned,
# Nearest to called: ancestor, stacked, modernise, integrating, pucker, photonic, geometry, ironic,
# Nearest to first: all, peary, carrier, oscars, label, the, apsaras, ipod,
# Nearest to pre: bukhari, speakers, mythological, nursultan, aara, vlan, samoa, organizing,
# Nearest to report: dea, borgo, motel, clark, mira, suzuki, hmc, haiku,
# Nearest to powers: neuroses, behaving, pbsuccess, papandreou, campomanes, schooner, decrease, censured,
# Nearest to freedom: socialism, flashlight, absentee, bioprospecting, boudica, houllier, axiology, bayous,
# Nearest to stage: maser, gleaned, time, pitchfork, simulated, symphonie, donation, microprogram,
# Nearest to quite: albeniz, homophonic, synchrotron, middle, before, custom, etymological, iambic,
# Nearest to smith: rennie, claudine, clarion, japan, assassination, xix, eddie, talents,
# Nearest to construction: highway, taunts, natural, hunky, expressways, russolo, acrylics, renormalization,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 4.0220 0.0932 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0385 0.0913 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 4.0892 0.0919 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 4.0209 0.0920 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0289 0.0917 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0407 0.0913 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0283 0.0913 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 4.0315 0.0921 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 4.0387 0.0919 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 4.0403 0.0918 sec/batch
# Nearest to use: used, document, purr, aerated, unheated, superoxide, bamberg, decibels,
# Nearest to for: mess, pendants, tabula, schottky, mcdonalds, commutes, factorials, hyphenated,
# Nearest to had: was, astor, wished, flee, faring, learned, bologna, nebulous,
# Nearest to and: in, dirigible, octopussy, style, north, chengdu, aragonese, ocho,
# Nearest to the: of, extraordinary, by, in, a, esquerra, repudiate, burgundians,
# Nearest to have: tidy, uk, magnate, nocs, latino, glasnevin, clerks, urology,
# Nearest to called: ancestor, modernise, stacked, integrating, comneni, ironic, albinus, birger,
# Nearest to first: all, carrier, peary, oscars, apsaras, label, the, motorbikes,
# Nearest to pre: bukhari, speakers, mythological, bernese, samoa, aara, dance, nursultan,
# Nearest to report: dea, borgo, motel, mira, suzuki, hmc, clark, findings,
# Nearest to powers: behaving, neuroses, pbsuccess, schooner, papandreou, campomanes, admirer, censured,
# Nearest to freedom: flashlight, bioprospecting, absentee, fail, rouen, boudica, abolition, axiology,
# Nearest to stage: gleaned, maser, pitchfork, simulated, microprogram, symphonie, time, nanometers,
# Nearest to quite: albeniz, synchrotron, homophonic, custom, malley, parthenon, stalls, iambic,
# Nearest to smith: rennie, claudine, eddie, sammy, pacino, clarion, assassination, japan,
# Nearest to construction: highway, expressways, taunts, natural, hunky, acrylics, renormalization, transportation,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 4.0117 0.0927 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9605 0.0917 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 4.0022 0.0915 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0597 0.0935 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0744 0.0919 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.1276 0.0920 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.1013 0.0934 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 4.0162 0.0916 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9920 0.0919 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 4.0210 0.0921 sec/batch
# Nearest to use: used, purr, aerated, document, superoxide, bamberg, thinkpad, unheated,
# Nearest to for: mess, pendants, commutes, mcdonalds, tabula, factorials, hyphenated, eraser,
# Nearest to had: astor, was, wished, faring, flee, learned, grammaticus, unpaid,
# Nearest to and: in, dirigible, fledgling, style, gravely, octopussy, ocho, masterful,
# Nearest to the: of, extraordinary, in, a, by, is, also, repudiate,
# Nearest to have: magnate, latino, tidy, phased, uk, missiles, glasnevin, fragmentation,
# Nearest to called: stacked, integrating, ancestor, either, ironic, modernise, comneni, apertures,
# Nearest to first: carrier, peary, all, oscars, apsaras, label, motorbikes, demonstration,
# Nearest to pre: bukhari, speakers, mythological, bernese, nursultan, aara, vlan, dance,
# Nearest to report: dea, borgo, findings, hmc, suzuki, clark, motel, mira,
# Nearest to powers: behaving, neuroses, pbsuccess, schooner, admirer, papandreou, censured, fgc,
# Nearest to freedom: flashlight, bioprospecting, rouen, boudica, houllier, mayer, socialism, anthropologist,
# Nearest to stage: maser, simulated, pitchfork, gleaned, time, symphonie, microprogram, audiences,
# Nearest to quite: albeniz, synchrotron, homophonic, iambic, malley, superficially, custom, stalls,
# Nearest to smith: rennie, claudine, clarion, masorti, assassination, eddie, pacino, sammy,
# Nearest to construction: highway, natural, taunts, expressways, hunky, acrylics, renormalization, schemes,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9519 0.0925 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9997 0.0918 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9881 0.0917 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9819 0.0920 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0367 0.0920 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9896 0.0888 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9698 0.0916 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9701 0.0939 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9807 0.0927 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9599 0.0925 sec/batch
# Nearest to use: used, document, purr, aerated, unheated, bamberg, superoxide, decibels,
# Nearest to for: mess, commutes, pendants, factorials, mcdonalds, tabula, schottky, misspellings,
# Nearest to had: astor, was, wished, flee, faring, learned, grammaticus, his,
# Nearest to and: in, dirigible, fledgling, vanadium, sand, style, as, the,
# Nearest to the: of, in, a, by, extraordinary, on, from, leste,
# Nearest to have: magnate, tidy, latino, phased, glasnevin, uk, nocs, missiles,
# Nearest to called: ancestor, integrating, modernise, stacked, albinus, ironic, comneni, detroiters,
# Nearest to first: peary, all, carrier, oscars, apsaras, nine, the, in,
# Nearest to pre: bukhari, mythological, bernese, speakers, nursultan, anthology, lusitanian, antiquity,
# Nearest to report: dea, hmc, pdf, suzuki, borgo, mira, findings, memo,
# Nearest to powers: behaving, neuroses, pbsuccess, admirer, schooner, fgc, papandreou, censured,
# Nearest to freedom: flashlight, bioprospecting, boudica, mayer, consignee, houllier, reckless, vergina,
# Nearest to stage: simulated, maser, gleaned, pitchfork, time, histological, microprogram, symphonie,
# Nearest to quite: albeniz, homophonic, synchrotron, iambic, malley, superficially, consummated, custom,
# Nearest to smith: rennie, clarion, claudine, masorti, assassination, sammy, japan, eddie,
# Nearest to construction: highway, expressways, taunts, natural, hunky, acrylics, russolo, rhone,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9596 0.0929 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8962 0.0920 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9607 0.0914 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9836 0.0917 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9658 0.0915 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.9485 0.0920 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8918 0.0918 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.9117 0.0917 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8997 0.0921 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.9535 0.0917 sec/batch
# Nearest to use: used, unheated, decibels, purr, aerated, keypad, superoxide, document,
# Nearest to for: mess, commutes, factorials, pendants, sometimes, schottky, tabula, eraser,
# Nearest to had: astor, was, flee, wished, learned, faring, umpires, bologna,
# Nearest to and: in, as, the, of, dirigible, attains, from, fledgling,
# Nearest to the: of, in, a, by, is, from, an, also,
# Nearest to have: phased, latino, magnate, kampuchea, missiles, nocs, so, sox,
# Nearest to called: ancestor, stacked, integrating, chiral, proportionately, america, incas, either,
# Nearest to first: all, carrier, peary, the, drifting, in, oscars, motorbikes,
# Nearest to pre: bukhari, speakers, mythological, bernese, faience, dance, anthology, illuminations,
# Nearest to report: dea, hmc, suzuki, borgo, pdf, arianespace, clark, mira,
# Nearest to powers: behaving, neuroses, pbsuccess, fgc, censured, admirer, schooner, kadena,
# Nearest to freedom: bioprospecting, flashlight, boudica, socialism, consignee, houllier, erred, freedoms,
# Nearest to stage: maser, simulated, pitchfork, gleaned, histological, microprogram, time, aroma,
# Nearest to quite: albeniz, synchrotron, homophonic, onset, stalls, superficially, consummated, temperatures,
# Nearest to smith: rennie, masorti, clarion, claudine, assassination, sammy, blackwood, genuineness,
# Nearest to construction: highway, expressways, natural, taunts, rhone, russolo, hunky, acrylics,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9809 0.0945 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9423 0.0919 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.9317 0.0923 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.9743 0.0919 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9900 0.0918 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8980 0.0920 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9348 0.0910 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9484 0.0913 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9528 0.0911 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9245 0.0920 sec/batch
# Nearest to use: used, unheated, document, keypad, decibels, purr, aerated, bamberg,
# Nearest to for: mess, factorials, commutes, urey, schottky, tabula, initialize, obtain,
# Nearest to had: was, astor, wished, learned, bologna, nebulous, flee, previously,
# Nearest to and: in, as, dirigible, the, octopussy, fledgling, of, from,
# Nearest to the: of, in, a, also, from, by, is, first,
# Nearest to have: latino, phased, tidy, uk, debugger, sox, sanctioned, urology,
# Nearest to called: integrating, ancestor, stacked, chiral, incas, modernise, ironic, america,
# Nearest to first: all, the, peary, oscars, in, carrier, drifting, nine,
# Nearest to pre: bukhari, mythological, dance, anthology, faience, speakers, vlan, illuminations,
# Nearest to report: dea, borgo, pdf, hmc, clark, suzuki, arianespace, motel,
# Nearest to powers: behaving, pbsuccess, neuroses, fgc, schooner, censured, papandreou, lurking,
# Nearest to freedom: bioprospecting, flashlight, vergina, freedoms, erred, axiology, consignee, reckless,
# Nearest to stage: maser, pitchfork, simulated, symphonie, time, gleaned, microprogram, histological,
# Nearest to quite: albeniz, homophonic, synchrotron, iambic, idiomatic, stalls, magnetized, superficially,
# Nearest to smith: rennie, clarion, claudine, blackwood, sammy, pacino, southey, masorti,
# Nearest to construction: highway, expressways, natural, renormalization, taunts, acrylics, russolo, sculptors,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9629 0.0929 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9212 0.0914 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.9414 0.0918 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9844 0.0915 sec/batch
# Epoch 5/10 Iteration: 21500 Avg. Training loss: 3.9647 0.0915 sec/batch
# Epoch 5/10 Iteration: 21600 Avg. Training loss: 3.9549 0.0923 sec/batch
# Epoch 5/10 Iteration: 21700 Avg. Training loss: 3.9687 0.0918 sec/batch
# Epoch 5/10 Iteration: 21800 Avg. Training loss: 3.9208 0.0917 sec/batch
# Epoch 5/10 Iteration: 21900 Avg. Training loss: 3.9188 0.0917 sec/batch
# Epoch 5/10 Iteration: 22000 Avg. Training loss: 3.9899 0.0916 sec/batch
# Nearest to use: used, unheated, document, keypad, aerated, decibels, superoxide, purr,
# Nearest to for: commutes, mess, factorials, mcdonalds, hyphenated, tabula, urey, arabic,
# Nearest to had: was, astor, learned, bologna, faring, wished, grammaticus, his,
# Nearest to and: in, as, the, of, from, fledgling, with, living,
# Nearest to the: of, in, by, a, also, and, from, which,
# Nearest to have: tidy, phased, some, blastocyst, debugger, so, magnate, missiles,
# Nearest to called: integrating, incas, ancestor, stacked, all, chiral, may, proportionately,
# Nearest to first: all, peary, carrier, in, drifting, oscars, the, motorbikes,
# Nearest to pre: bukhari, mythological, dance, anthology, illuminations, faience, speakers, bernese,
# Nearest to report: dea, pdf, borgo, assessment, clark, hmc, arianespace, haiku,
# Nearest to powers: behaving, neuroses, pbsuccess, fgc, censured, schooner, papandreou, utub,
# Nearest to freedom: bioprospecting, boudica, flashlight, vergina, consignee, freedoms, reckless, axiology,
# Nearest to stage: simulated, time, pitchfork, maser, symphonie, gleaned, umbilical, shilton,
# Nearest to quite: albeniz, synchrotron, magnetized, iambic, homophonic, consummated, superficially, idiomatic,
# Nearest to smith: rennie, claudine, clarion, blackwood, masorti, sammy, southey, pacino,
# Nearest to construction: highway, expressways, natural, taunts, acrylics, rhone, russolo, sculptors,
# Epoch 5/10 Iteration: 22100 Avg. Training loss: 3.9412 0.0926 sec/batch
# Epoch 5/10 Iteration: 22200 Avg. Training loss: 4.0619 0.0959 sec/batch
# Epoch 5/10 Iteration: 22300 Avg. Training loss: 4.0129 0.0938 sec/batch
# Epoch 5/10 Iteration: 22400 Avg. Training loss: 3.9989 0.0921 sec/batch
# Epoch 5/10 Iteration: 22500 Avg. Training loss: 3.9264 0.0922 sec/batch
# Epoch 5/10 Iteration: 22600 Avg. Training loss: 3.8810 0.0918 sec/batch
# Epoch 5/10 Iteration: 22700 Avg. Training loss: 3.9496 0.0917 sec/batch
# Epoch 5/10 Iteration: 22800 Avg. Training loss: 3.8893 0.0919 sec/batch
# Epoch 5/10 Iteration: 22900 Avg. Training loss: 3.9533 0.0924 sec/batch
# ...
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8389 0.0931 sec/batch
# Epoch 9/10 Iteration: 38200 Avg. Training loss: 3.7185 0.0920 sec/batch
# Epoch 9/10 Iteration: 38300 Avg. Training loss: 3.7980 0.0916 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.7060 0.0912 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7789 0.0920 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.8110 0.0921 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.7979 0.0913 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7685 0.0917 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.8074 0.0914 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8610 0.0955 sec/batch
# Nearest to use: used, decibels, refer, keypad, also, entering, document, unheated,
# Nearest to for: the, and, of, in, a, which, also, as,
# Nearest to had: was, his, astor, learned, meanwhile, were, ever, bologna,
# Nearest to and: in, of, as, the, by, a, for, from,
# Nearest to the: of, a, in, also, from, is, and, by,
# Nearest to have: because, are, some, there, many, that, been, most,
# Nearest to called: as, a, in, all, the, or, which, ime,
# Nearest to first: in, all, the, a, after, later, end, early,
# Nearest to pre: originated, unwillingly, sai, amf, illuminations, antiquity, lusitanian, ultimate,
# Nearest to report: dea, pdf, subpoenaed, briefing, ginsberg, usda, arianespace, reports,
# Nearest to powers: entity, behaving, beings, neuroses, lurking, foci, receiver, fgc,
# Nearest to freedom: freedoms, bioprospecting, boudica, vergina, axiology, restrict, dalit, succesor,
# Nearest to stage: pitchfork, umbilical, simulated, time, fetus, entitled, almirante, lettres,
# Nearest to quite: magnetized, sheer, tottenham, graeco, heywood, octane, albeniz, idiomatic,
# Nearest to smith: blackwood, rennie, argues, clarion, doomsday, saxophone, nichols, claudine,
# Nearest to construction: highway, rhone, crawling, shipbuilding, southfield, escherichia, planned, interchange,
# Epoch 9/10 Iteration: 39100 Avg. Training loss: 3.7634 0.0937 sec/batch
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7969 0.0914 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7637 0.0911 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.8244 0.0913 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.8003 0.0914 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.8112 0.0918 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7961 0.0916 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7831 0.0917 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8270 0.0921 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.8341 0.0917 sec/batch
# Nearest to use: used, decibels, keypad, refer, also, document, unheated, entering,
# Nearest to for: and, in, the, of, a, which, also, as,
# Nearest to had: was, his, learned, meanwhile, were, astor, descendant, bologna,
# Nearest to and: in, of, as, the, a, by, from, for,
# Nearest to the: of, a, in, also, and, from, by, is,
# Nearest to have: because, are, some, there, that, many, been, of,
# Nearest to called: as, in, a, the, of, first, all, and,
# Nearest to first: in, all, a, the, after, later, early, end,
# Nearest to pre: originated, sai, unwillingly, amf, illuminations, remains, antiquity, lusitanian,
# Nearest to report: pdf, dea, subpoenaed, ginsberg, briefing, arianespace, usda, hist,
# Nearest to powers: entity, behaving, lurking, role, neuroses, beings, foci, schooner,
# Nearest to freedom: freedoms, vergina, bioprospecting, wish, boudica, restrict, succesor, axiology,
# Nearest to stage: pitchfork, simulated, time, entitled, umbilical, lettres, starkly, fetus,
# Nearest to quite: magnetized, sheer, tottenham, bereft, graeco, temperatures, heywood, synchrotron,
# Nearest to smith: blackwood, rennie, argues, clarion, saxophone, solos, doomsday, lathe,
# Nearest to construction: highway, rhone, shipbuilding, planned, southfield, built, escherichia, expressways,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.8261 0.0928 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7951 0.0932 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7979 0.0915 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7433 0.0919 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8724 0.0918 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.8165 0.0923 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.9375 0.0918 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.8098 0.0918 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8580 0.0912 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7567 0.0915 sec/batch
# Nearest to use: used, refer, also, decibels, keypad, unheated, denote, uses,
# Nearest to for: the, and, in, of, a, which, as, also,
# Nearest to had: was, his, learned, meanwhile, collapse, ever, astor, later,
# Nearest to and: in, of, as, the, a, by, from, with,
# Nearest to the: of, a, in, and, also, from, by, on,
# Nearest to have: because, some, are, there, many, they, been, that,
# Nearest to called: as, a, the, or, ime, which, all, gretchen,
# Nearest to first: in, all, later, the, after, a, by, was,
# Nearest to pre: originated, sai, unwillingly, antiquity, illuminations, remains, amf, roshan,
# Nearest to report: dea, pdf, subpoenaed, briefing, assessment, ginsberg, hist, arianespace,
# Nearest to powers: behaving, entity, lurking, neuroses, beings, role, foci, character,
# Nearest to freedom: freedoms, vergina, bioprospecting, boudica, restrict, succesor, axiology, wish,
# Nearest to stage: pitchfork, simulated, umbilical, fetus, entitled, lettres, almirante, starkly,
# Nearest to quite: magnetized, sheer, graeco, heywood, tottenham, octane, temperatures, bereft,
# Nearest to smith: blackwood, argues, rennie, clarion, masorti, lathe, saxophone, doomsday,
# Nearest to construction: highway, rhone, southfield, crawling, planned, shipbuilding, natural, unionized,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.7349 0.0937 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.8120 0.0919 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.7331 0.0913 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.7916 0.0917 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7891 0.0919 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7975 0.0917 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.8114 0.0617 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.8170 0.0915 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7687 0.0920 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.8129 0.0917 sec/batch
# Nearest to use: used, refer, also, decibels, unheated, keypad, uses, dmg,
# Nearest to for: and, in, of, the, a, also, to, which,
# Nearest to had: was, his, learned, meanwhile, later, were, astor, ever,
# Nearest to and: in, of, as, the, a, by, from, for,
# Nearest to the: of, in, a, from, and, also, by, on,
# Nearest to have: because, some, there, are, many, that, been, so,
# Nearest to called: as, a, the, in, of, which, first, all,
# Nearest to first: in, the, all, after, later, a, one, end,
# Nearest to pre: originated, sai, unwillingly, antiquity, remains, in, amf, illuminations,
# Nearest to report: pdf, subpoenaed, dea, ginsberg, hist, briefing, chaldeans, arianespace,
# Nearest to powers: entity, behaving, beings, lurking, foci, neuroses, character, entities,
# Nearest to freedom: freedoms, bioprospecting, vergina, boudica, succesor, lawrence, carlisle, restrict,
# Nearest to stage: pitchfork, time, simulated, umbilical, lettres, fetus, almirante, gallbladder,
# Nearest to quite: magnetized, tottenham, sheer, heywood, graeco, octane, healers, synchrotron,
# Nearest to smith: blackwood, argues, rennie, lathe, clarion, masorti, saxophone, southey,
# Nearest to construction: highway, rhone, crawling, southfield, built, planned, unionized, expressways,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7522 0.0928 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7569 0.0919 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7718 0.0920 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7600 0.0949 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7939 0.0921 sec/batch
# Epoch 10/10 Iteration: 42600 Avg. Training loss: 3.7668 0.0921 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.8109 0.0920 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6848 0.0916 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7829 0.0929 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.7259 0.0926 sec/batch
# Nearest to use: used, refer, also, decibels, keypad, uses, unheated, dmg,
# Nearest to for: in, and, the, of, a, which, is, also,
# Nearest to had: was, were, learned, his, meanwhile, ever, astor, later,
# Nearest to and: in, of, the, as, a, by, is, for,
# Nearest to the: of, a, in, is, from, and, by, also,
# Nearest to have: because, some, are, there, many, that, been, since,
# Nearest to called: as, a, the, of, in, all, or, which,
# Nearest to first: in, all, the, a, later, by, after, end,
# Nearest to pre: originated, sai, unwillingly, remains, amf, roshan, in, antiquity,
# Nearest to report: pdf, subpoenaed, briefing, arianespace, dea, ginsberg, usda, assessment,
# Nearest to powers: entity, foci, lurking, entities, behaving, beings, bicameral, character,
# Nearest to freedom: freedoms, bioprospecting, vergina, boudica, succesor, restrict, lawrence, wish,
# Nearest to stage: pitchfork, umbilical, simulated, stabilizer, almirante, fetus, time, gallbladder,
# Nearest to quite: magnetized, octane, tottenham, produced, graeco, sheer, heywood, healers,
# Nearest to smith: argues, blackwood, rennie, clarion, masorti, southey, lathe, saxophone,
# Nearest to construction: highway, rhone, planned, crawling, architectural, unionized, expressways, southfield,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6806 0.0932 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7539 0.0917 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7971 0.0917 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7897 0.0913 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7366 0.0932 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.8457 0.0916 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7728 0.0920 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7676 0.0918 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7509 0.0917 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.8108 0.0915 sec/batch
# Nearest to use: used, also, refer, decibels, keypad, uses, often, other,
# Nearest to for: in, the, and, a, of, which, also, to,
# Nearest to had: was, were, learned, meanwhile, ever, his, later, previously,
# Nearest to and: in, the, of, as, a, by, for, with,
# Nearest to the: of, a, in, is, also, and, from, by,
# Nearest to have: are, there, some, because, many, been, that, they,
# Nearest to called: a, as, the, in, of, or, which, all,
# Nearest to first: in, all, the, a, after, early, by, later,
# Nearest to pre: originated, sai, unwillingly, remains, amf, roshan, qualifies, decades,
# Nearest to report: pdf, subpoenaed, dea, briefing, ginsberg, arianespace, assessment, usda,
# Nearest to powers: entity, lurking, beings, behaving, entities, neuroses, foci, character,
# Nearest to freedom: freedoms, bioprospecting, restrict, vergina, succesor, lawrence, boudica, axiology,
# Nearest to stage: pitchfork, umbilical, time, entitled, simulated, lettres, fetus, ibex,
# Nearest to quite: magnetized, graeco, tottenham, sheer, there, heywood, produced, bereft,
# Nearest to smith: argues, blackwood, rennie, clarion, saxophone, southey, nichols, doomsday,
# Nearest to construction: highway, rhone, crawling, planned, architectural, southfield, escherichia, interchange,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7799 0.0931 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7908 0.0920 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7893 0.0911 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7690 0.0926 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.8201 0.0918 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.8074 0.0919 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7717 0.0915 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7967 0.0914 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7641 0.0913 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7535 0.0919 sec/batch
# Nearest to use: used, refer, also, decibels, keypad, uses, widely, or,
# Nearest to for: the, in, and, of, a, which, as, to,
# Nearest to had: was, meanwhile, learned, were, his, ever, later, s,
# Nearest to and: in, the, as, of, a, by, with, from,
# Nearest to the: of, in, a, also, and, by, from, is,
# Nearest to have: some, are, because, there, many, since, that, been,
# Nearest to called: as, a, the, in, first, which, of, all,
# Nearest to first: in, all, a, after, the, later, one, was,
# Nearest to pre: originated, sai, unwillingly, remains, amf, antiquity, roshan, in,
# Nearest to report: pdf, assessment, subpoenaed, arianespace, reports, dea, briefing, usda,
# Nearest to powers: behaving, entity, beings, lurking, foci, neuroses, embodiment, entities,
# Nearest to freedom: freedoms, restrict, bioprospecting, vergina, lawrence, boudica, axiology, succesor,
# Nearest to stage: pitchfork, umbilical, simulated, fetus, gleaned, ibex, adhering, entitled,
# Nearest to quite: magnetized, produced, graeco, heywood, tottenham, octane, there, sheer,
# Nearest to smith: argues, blackwood, rennie, clarion, saxophone, southey, nichols, lathe,
# Nearest to construction: highway, rhone, planned, crawling, escherichia, built, unionized, southfield,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.7877 0.0932 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.8024 0.0924 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8907 0.0917 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8527 0.0913 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.8336 0.0912 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7463 0.0920 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.7195 0.0922 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7332 0.0938 sec/batch
# Epoch 10/10 Iteration: 45900 Avg. Training loss: 3.7090 0.0916 sec/batch
# Epoch 10/10 Iteration: 46000 Avg. Training loss: 3.7920 0.0916 sec/batch
# Nearest to use: used, also, refer, decibels, keypad, extensively, uses, widely,
# Nearest to for: the, in, and, a, of, as, also, which,
# Nearest to had: was, his, learned, later, meanwhile, were, s, ever,
# Nearest to and: in, the, as, of, a, by, for, with,
# Nearest to the: of, a, in, and, also, from, by, is,
# Nearest to have: are, some, because, there, many, since, been, that,
# Nearest to called: as, a, the, or, which, in, ime, gretchen,
# Nearest to first: in, all, the, later, after, a, by, last,
# Nearest to pre: originated, sai, unwillingly, remains, amf, antiquity, roshan, decades,
# Nearest to report: pdf, briefing, subpoenaed, assessment, ginsberg, reports, dea, arianespace,
# Nearest to powers: entity, lurking, behaving, character, beings, neuroses, entities, foci,
# Nearest to freedom: freedoms, restrict, bioprospecting, vergina, lawrence, dalit, boudica, succesor,
# Nearest to stage: pitchfork, umbilical, entitled, simulated, fetus, almirante, gallbladder, lettres,
# Nearest to quite: tottenham, magnetized, produced, sheer, there, octane, heywood, bereft,
# Nearest to smith: argues, blackwood, rennie, southey, saxophone, clarion, lathe, nichols,
# Nearest to construction: highway, rhone, crawling, planned, escherichia, russolo, receipts, southfield,
# Epoch 10/10 Iteration: 46100 Avg. Training loss: 3.8045 0.0930 sec/batch
# Epoch 10/10 Iteration: 46200 Avg. Training loss: 3.7636 0.0917 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
